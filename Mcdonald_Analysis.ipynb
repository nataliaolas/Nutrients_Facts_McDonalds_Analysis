# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv("D:/mcdonald/menu.csv") #Loading dataset

# %%
df.head(10) #generate the first 10 row of the dataset
# Out:
#     Category                                               Item  \
# 0  Breakfast                                       Egg McMuffin
# 1  Breakfast                                  Egg White Delight
# 2  Breakfast                                   Sausage McMuffin
# 3  Breakfast                          Sausage McMuffin with Egg
# 4  Breakfast                   Sausage McMuffin with Egg Whites
# 5  Breakfast                               Steak & Egg McMuffin
# 6  Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7  Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
#
#      Serving Size  Calories  Calories from Fat  Total Fat  \
# 0  4.8 oz (136 g)       300                120       13.0
# 1  4.8 oz (135 g)       250                 70        8.0
# 2  3.9 oz (111 g)       370                200       23.0
# ...

# %%
df.columns #get name of columns of dataset
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df.describe(include='all') #generate the statistics
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
df.info() #get the info about datasets and types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.isnull().sum() #checking null value in datasets
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
df.Category.unique() #get the categories
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %% [markdown]
# 1. Ranking McDonalds items with the most calories

# %%
meal = df.query('Category != "Beverages" and Category !=  "Coffee & Tea" and Category != "Smoothies & Shakes"') #generate all meals without drinks 
meal.Category.unique()
meals_cal = pd.DataFrame({'Item': meal.Item, 'Calories': meal.Calories}) # Select only Items and Calories columns
meals_sort = meals_cal.sort_values('Calories', ascending=True) # Sort by calories
meals_sort.plot.barh(x='Item', y='Calories', figsize= (10,40), color='red') 
plt.show()

# %% [markdown]
# 2. How many calories does the average McDonald's meal contain?

# %%
brkfst = df.loc[df.Category =='Breakfast']
bandp = df.loc[df.Category == 'Beef & Pork']
chandfish = df.loc[df.Category == 'Chicken & Fish']
sal = df.loc[df.Category == 'Salads']
snands = df.loc[df.Category == 'Snacks & Sides']
dess = df.loc[df.Category == 'Desserts']

# %%
average_calories_category = round(brkfst['Calories'].mean(axis=0),1),round(bandp['Calories'].mean(axis=0),1), round(chandfish['Calories'].mean(axis=0),1), round(sal['Calories'].mean(axis=0),1), round(snands['Calories'].mean(axis=0),1),round(dess['Calories'].mean(axis=0),1) 
index = ['Breakfast','Beef & Pork', 'Chicken & Fish', 'Salads','Snacks & Sides', 'Desserts']
avg_cat= pd.DataFrame({'Avg Calories': average_calories_category}, index=index)
fig = avg_cat.plot.bar(rot=0, color='red', figsize =(10,8), title='Average calories for each category')
fig.set_xlabel('Categories')
fig.set_ylabel('Calorie')

for bar in fig.patches:
    fig.annotate(str(bar.get_height()), (bar.get_x() * 1.045, bar.get_height() * 1.012))

# %% [markdown]
# 4. Plots for nutritions, compared with maximum amount recommended for an adult diet
# plt.figure(figsize=(16,3))

# %%
#Average amount of saturated fat compared to the maximum amount recommended for an adult diet
plt.figure(figsize=(16,3))
sns.barplot(x=df.groupby('Category')['Saturated Fat'].mean().index, y=df.groupby('Category')['Saturated Fat'].mean().values)
plt.title('Average amount of saturated fat compared to the maximum amount recommended for an adult diet ')
plt.ylabel('Saturate Fat')
plt.xlabel('Category')
plt.axhline(y=16,color='red',linewidth=4) #16 g for one adult person per day

# %%
#Average amount of sugares compared to the maximum amount recommended for an adult diet
plt.figure(figsize=(16,3))
sns.barplot(x=df.groupby('Category')['Sugars'].mean().index, y=df.groupby('Category')['Sugars'].mean().values)
plt.title('Average amount of sugars compared to the maximum amount recommended for an adult diet')
plt.ylabel('Sugar')
plt.xlabel('Category')
plt.axhline(y=50,color='red',linewidth=4) #50 g for one adult person per day

# %%
#Average amount of cholesterol compared to the maximum amount recommended for an adult diet
plt.figure(figsize=(16,3))
sns.barplot(x=df.groupby('Category')['Cholesterol'].mean().index, y=df.groupby('Category')['Cholesterol'].mean().values)
plt.title('Average amount of cholesterols compared to the maximum amount recommended for an adult diet')
plt.ylabel('Cholesterol')
plt.xlabel('Category')
plt.axhline(y=180,color='red',linewidth=4) #180 mg for one adult person per day

# %% [markdown]
# 5. Correlation between nutritions

# %%
nutrition = [
 'Calories',
 'Calories from Fat',
 'Total Fat',
 'Saturated Fat',
 'Trans Fat',
 'Cholesterol',
 'Sodium',
 'Carbohydrates',
 'Dietary Fiber',
 'Sugars',
 'Protein',
 'Vitamin A (% Daily Value)',
 'Vitamin C (% Daily Value)',
 'Calcium (% Daily Value)',
 'Iron (% Daily Value)'
 ]

correl = df[nutrition].corr()
fig = plt.figure(figsize = (15,15))
sns.heatmap(correl, square=True, cmap='vlag', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 6. Meal with the most amount of protein

# %%
max_protein = df['Protein'].idxmax()
row_max_protein = df.loc[max_protein]
row_max_protein
# Out:
# Category                                       Chicken & Fish
# Item                             Chicken McNuggets (40 piece)
# Serving Size                                  22.8 oz (646 g)
# Calories                                                 1880
# Calories from Fat                                        1060
# Total Fat                                               118.0
# Total Fat (% Daily Value)                                 182
# Saturated Fat                                            20.0
# Saturated Fat (% Daily Value)                             101
# Trans Fat                                                 1.0
# Cholesterol                                               265
# Cholesterol (% Daily Value)                                89
# Sodium                                                   3600
# Sodium (% Daily Value)                                    150
# Carbohydrates                                             118
# ...

# %% [markdown]
# 7. Other analysis

# %%
ranking_proteins = df.sort_values(by='Protein',ascending=False)
ranking_proteins.head(10)
# Out:
#           Category                                       Item  \
# 82  Chicken & Fish               Chicken McNuggets (40 piece)
# 47     Beef & Pork         Double Quarter Pounder with Cheese
# 81  Chicken & Fish               Chicken McNuggets (20 piece)
# 64  Chicken & Fish   Bacon Clubhouse Grilled Chicken Sandwich
# 60  Chicken & Fish      Premium Grilled Chicken Club Sandwich
# 51     Beef & Pork                     Bacon Clubhouse Burger
# 45     Beef & Pork  Quarter Pounder with Bacon Habanero Ranch
# 44     Beef & Pork        Quarter Pounder with Bacon & Cheese
# 63  Chicken & Fish    Bacon Clubhouse Crispy Chicken Sandwich
# 59  Chicken & Fish       Premium Crispy Chicken Club Sandwich
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 82  22.8 oz (646 g)      1880               1060      118.0
# 47    10 oz (283 g)       750                380       43.0
# 81  11.4 oz (323 g)       940                530       59.0
# ...

# %%
df.query('Category == "Desserts" and Calories <200').head()
# Out:
#      Category                   Item     Serving Size  Calories  \
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 104                 70        8.0                         12            3.5
# 105                 50        6.0                          9            2.5
# 106                 10        1.5                          2            1.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 104                             19        0.0  ...
# 105                             13        0.0  ...
# 106                              4        0.0  ...
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 104                              7              1
# 105                              7              1
# ...
